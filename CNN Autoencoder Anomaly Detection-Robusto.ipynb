# %% [markdown]
# https://medium.com/@judewells/image-anomaly-detection-novelty-detection-using-convolutional-auto-encoders-in-keras-1c31321c10f2

# %%
import os
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
import matplotlib.pyplot as plt
from keras import backend as K
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from PIL import Image, ImageChops
from sklearn.neighbors import KernelDensity
import random
# Out:
# Using TensorFlow backend.

# %%
matplotlib inline

# %%
# Create generators for training, validation and testing
# Generate data from the images in a folder, allows use of datasets that do not fit in main memory all at once
# Image resizing is done by the generator so a folder with any sized-images can be used
# The named directory must contain one or more subfolders, path should look like apples_train/apple_class1/img1.jpg...

batch_size = 85
train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
train_generator = train_datagen.flow_from_directory(
    'robusto_train/',
    target_size=(128, 128),
    batch_size=batch_size,
    class_mode='input'
    )

test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
validation_generator = test_datagen.flow_from_directory(
    'robusto_test/',
    target_size=(128, 128),
    batch_size=batch_size,
    class_mode='input'
    )

anomaly_generator = test_datagen.flow_from_directory(
    'eggplant/',
    target_size=(96, 96),
    batch_size=batch_size,
    class_mode='input'
    )
# Out:
# Found 142 images belonging to 1 classes.
# Found 45 images belonging to 1 classes.
# Found 468 images belonging to 3 classes.

# %%
# Define the convolutional autoencoder model 
# input shape must be the same size as the images that will be fed into it by the generators
# The output layer must be the same dimensions as the original image
model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same',activation='relu', input_shape=(128, 128, 3)))
model.add(MaxPooling2D(pool_size=(4,4), padding='same')) # using pool_size (4,4) makes the layer 4x smaller in height and width

model.add(Conv2D(8,(3, 3),activation='relu',  padding='same'))
model.add(MaxPooling2D(pool_size=(4,4), padding='same'))

model.add(Conv2D(3,(3, 3),activation='relu',  padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), padding='same'))

#-------------------------
model.add(Conv2D(3,(3, 3),activation='relu',  padding='same'))
model.add(UpSampling2D((2, 2)))

model.add(Conv2D(8,(3, 3),activation='relu',  padding='same'))
model.add(UpSampling2D((4, 4)))

model.add(Conv2D(16,(3, 3),activation='relu',  padding='same'))
model.add(UpSampling2D((4, 4)))

model.add(Conv2D(3,(3, 3), activation='sigmoid', padding='same'))
#-------------------------

model.summary()

# Compile the model
model.compile(optimizer='adadelta', loss='mean_squared_error')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 128, 128, 16)      448
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 8)         1160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 3)           219
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 3)           0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 3)           84
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 8, 8, 3)           0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 8)           224
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 16)        1168
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 128, 128, 3)       435
# =================================================================
# Total params: 3,738
# Trainable params: 3,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(os.getcwd())
# Out:
# C:\Users\SESA67051\Documents\GitHub\keras_anomaly_detection

# %%
# Training the model
es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30) # Early stopping (stops training when validation doesn't improve for {patience} epochs)
model_filepath = 'models/model1.keras'
save_best = keras.callbacks.ModelCheckpoint(model_filepath, monitor='val_loss', save_best_only=True, mode='min') # Saves the best version of the model to disk (as measured on the validation data set)
model.fit_generator(
        train_generator,
        steps_per_epoch=1000 // batch_size,
        epochs=200,
        validation_data=validation_generator,
        validation_steps=1000 // batch_size,
        shuffle = True,
        callbacks=[es, save_best])
# Out:
# Epoch 1/200
# 11/11 [==============================] - 4s 405ms/step - loss: 0.0303 - val_loss: 0.0345
# Epoch 2/200
# 11/11 [==============================] - 4s 370ms/step - loss: 0.0304 - val_loss: 0.0343
# Epoch 3/200
# 11/11 [==============================] - 4s 373ms/step - loss: 0.0306 - val_loss: 0.0345
# Epoch 4/200
# 11/11 [==============================] - 5s 412ms/step - loss: 0.0303 - val_loss: 0.0340
# Epoch 5/200
# 11/11 [==============================] - 4s 354ms/step - loss: 0.0304 - val_loss: 0.0344
# Epoch 6/200
# 11/11 [==============================] - 4s 357ms/step - loss: 0.0302 - val_loss: 0.0337
# Epoch 7/200
# 11/11 [==============================] - 5s 410ms/step - loss: 0.0299 - val_loss: 0.0336
# Epoch 8/200
# 11/11 [==============================] - 4s 371ms/step - loss: 0.0295 - val_loss: 0.0334
# Epoch 9/200
# 11/11 [==============================] - 4s 364ms/step - loss: 0.0294 - val_loss: 0.0333
# Epoch 10/200
# 11/11 [==============================] - 4s 363ms/step - loss: 0.0298 - val_loss: 0.0344
# Epoch 11/200
# 11/11 [==============================] - 4s 357ms/step - loss: 0.0295 - val_loss: 0.0331
# Epoch 12/200
# 11/11 [==============================] - 4s 401ms/step - loss: 0.0294 - val_loss: 0.0334
# Epoch 13/200
# 11/11 [==============================] - 4s 384ms/step - loss: 0.0294 - val_loss: 0.0331
# Epoch 14/200
# 11/11 [==============================] - 5s 493ms/step - loss: 0.0296 - val_loss: 0.0340
# Epoch 15/200
# 11/11 [==============================] - 4s 346ms/step - loss: 0.0295 - val_loss: 0.0329
# Epoch 16/200
# 11/11 [==============================] - 4s 363ms/step - loss: 0.0291 - val_loss: 0.0337
# Epoch 17/200
# 11/11 [==============================] - 4s 393ms/step - loss: 0.0294 - val_loss: 0.0331
# Epoch 18/200
# 11/11 [==============================] - 4s 385ms/step - loss: 0.0294 - val_loss: 0.0335
# Epoch 19/200
# 11/11 [==============================] - 4s 346ms/step - loss: 0.0289 - val_loss: 0.0327
# Epoch 20/200
# 11/11 [==============================] - 5s 410ms/step - loss: 0.0287 - val_loss: 0.0326
# Epoch 21/200
# 11/11 [==============================] - 4s 371ms/step - loss: 0.0289 - val_loss: 0.0329
# Epoch 22/200
# 11/11 [==============================] - 4s 367ms/step - loss: 0.0288 - val_loss: 0.0329
# Epoch 23/200
# 11/11 [==============================] - 4s 346ms/step - loss: 0.0289 - val_loss: 0.0328
# Epoch 24/200
# 11/11 [==============================] - 5s 423ms/step - loss: 0.0287 - val_loss: 0.0324
# Epoch 25/200
# 11/11 [==============================] - 4s 379ms/step - loss: 0.0287 - val_loss: 0.0331
# Epoch 26/200
# 11/11 [==============================] - 4s 359ms/step - loss: 0.0286 - val_loss: 0.0322
# Epoch 27/200
# 11/11 [==============================] - 4s 350ms/step - loss: 0.0282 - val_loss: 0.0322
# Epoch 28/200
# 11/11 [==============================] - 4s 407ms/step - loss: 0.0284 - val_loss: 0.0332
# Epoch 29/200
# 11/11 [==============================] - 5s 470ms/step - loss: 0.0286 - val_loss: 0.0321
# Epoch 30/200
# 11/11 [==============================] - 4s 367ms/step - loss: 0.0283 - val_loss: 0.0329
# Epoch 31/200
# 11/11 [==============================] - 5s 434ms/step - loss: 0.0284 - val_loss: 0.0322
# Epoch 32/200
# 11/11 [==============================] - 4s 364ms/step - loss: 0.0282 - val_loss: 0.0320
# Epoch 33/200
# 11/11 [==============================] - 4s 358ms/step - loss: 0.0279 - val_loss: 0.0320
# Epoch 34/200
# 11/11 [==============================] - 5s 473ms/step - loss: 0.0282 - val_loss: 0.0322
# Epoch 35/200
# 11/11 [==============================] - 4s 377ms/step - loss: 0.0281 - val_loss: 0.0321
# Epoch 36/200
# 11/11 [==============================] - 4s 382ms/step - loss: 0.0280 - val_loss: 0.0318
# Epoch 37/200
# 11/11 [==============================] - 4s 355ms/step - loss: 0.0279 - val_loss: 0.0327
# Epoch 38/200
# 11/11 [==============================] - 4s 402ms/step - loss: 0.0282 - val_loss: 0.0318
# Epoch 39/200
# 11/11 [==============================] - 4s 392ms/step - loss: 0.0277 - val_loss: 0.0317
# Epoch 40/200
# 11/11 [==============================] - 5s 414ms/step - loss: 0.0276 - val_loss: 0.0321
# Epoch 41/200
# 11/11 [==============================] - 4s 361ms/step - loss: 0.0280 - val_loss: 0.0317
# Epoch 42/200
# 11/11 [==============================] - 4s 405ms/step - loss: 0.0278 - val_loss: 0.0323
# Epoch 43/200
# 11/11 [==============================] - 4s 378ms/step - loss: 0.0276 - val_loss: 0.0316
# Epoch 44/200
# 11/11 [==============================] - 5s 415ms/step - loss: 0.0274 - val_loss: 0.0317
# Epoch 45/200
# 11/11 [==============================] - 5s 433ms/step - loss: 0.0274 - val_loss: 0.0314
# Epoch 46/200
# 11/11 [==============================] - 4s 378ms/step - loss: 0.0275 - val_loss: 0.0320
# Epoch 47/200
# 11/11 [==============================] - 4s 360ms/step - loss: 0.0277 - val_loss: 0.0317
# Epoch 48/200
# 11/11 [==============================] - 4s 373ms/step - loss: 0.0275 - val_loss: 0.0319
# Epoch 49/200
# 11/11 [==============================] - 4s 360ms/step - loss: 0.0273 - val_loss: 0.0312
# Epoch 50/200
# 11/11 [==============================] - 4s 407ms/step - loss: 0.0272 - val_loss: 0.0316
# Epoch 51/200
# 11/11 [==============================] - 4s 360ms/step - loss: 0.0274 - val_loss: 0.0315
# Epoch 52/200
# 11/11 [==============================] - 4s 392ms/step - loss: 0.0275 - val_loss: 0.0312
# Epoch 53/200
# 11/11 [==============================] - 4s 374ms/step - loss: 0.0270 - val_loss: 0.0314
# Epoch 54/200
# 11/11 [==============================] - 5s 474ms/step - loss: 0.0270 - val_loss: 0.0310
# Epoch 55/200
# 11/11 [==============================] - 5s 422ms/step - loss: 0.0274 - val_loss: 0.0321
# Epoch 56/200
# 11/11 [==============================] - 4s 409ms/step - loss: 0.0271 - val_loss: 0.0310
# Epoch 57/200
# 11/11 [==============================] - 5s 419ms/step - loss: 0.0272 - val_loss: 0.0321
# Epoch 58/200
# 11/11 [==============================] - 4s 378ms/step - loss: 0.0270 - val_loss: 0.0308
# Epoch 59/200
# 11/11 [==============================] - 5s 414ms/step - loss: 0.0270 - val_loss: 0.0315
# Epoch 60/200
# 11/11 [==============================] - 4s 380ms/step - loss: 0.0270 - val_loss: 0.0312
# Epoch 61/200
# 11/11 [==============================] - 4s 361ms/step - loss: 0.0268 - val_loss: 0.0309
# Epoch 62/200
# 11/11 [==============================] - 4s 399ms/step - loss: 0.0266 - val_loss: 0.0307
# Epoch 63/200
# 11/11 [==============================] - 4s 359ms/step - loss: 0.0271 - val_loss: 0.0313
# Epoch 64/200
# 11/11 [==============================] - 4s 379ms/step - loss: 0.0266 - val_loss: 0.0308
# Epoch 65/200
# 11/11 [==============================] - 4s 372ms/step - loss: 0.0267 - val_loss: 0.0309
# Epoch 66/200
# 11/11 [==============================] - 5s 454ms/step - loss: 0.0263 - val_loss: 0.0305
# Epoch 67/200
# 11/11 [==============================] - 5s 490ms/step - loss: 0.0264 - val_loss: 0.0309
# Epoch 68/200
# 11/11 [==============================] - 4s 405ms/step - loss: 0.0265 - val_loss: 0.0307
# Epoch 69/200
# 11/11 [==============================] - 4s 363ms/step - loss: 0.0267 - val_loss: 0.0310
# Epoch 70/200
# 11/11 [==============================] - 5s 415ms/step - loss: 0.0265 - val_loss: 0.0304
# Epoch 71/200
# 11/11 [==============================] - 4s 360ms/step - loss: 0.0269 - val_loss: 0.0313
# Epoch 72/200
# 11/11 [==============================] - 5s 424ms/step - loss: 0.0267 - val_loss: 0.0304
# Epoch 73/200
# 11/11 [==============================] - 5s 428ms/step - loss: 0.0262 - val_loss: 0.0303
# Epoch 74/200
# 11/11 [==============================] - 5s 439ms/step - loss: 0.0261 - val_loss: 0.0303
# Epoch 75/200
# 11/11 [==============================] - 5s 425ms/step - loss: 0.0263 - val_loss: 0.0314
# Epoch 76/200
# 11/11 [==============================] - 5s 475ms/step - loss: 0.0265 - val_loss: 0.0303
# Epoch 77/200
# 11/11 [==============================] - 5s 428ms/step - loss: 0.0264 - val_loss: 0.0309
# Epoch 78/200
# 11/11 [==============================] - 5s 433ms/step - loss: 0.0263 - val_loss: 0.0302
# Epoch 79/200
# 11/11 [==============================] - 5s 434ms/step - loss: 0.0264 - val_loss: 0.0310
# Epoch 80/200
# 11/11 [==============================] - 5s 432ms/step - loss: 0.0261 - val_loss: 0.0303
# Epoch 81/200
# 11/11 [==============================] - 5s 418ms/step - loss: 0.0262 - val_loss: 0.0301
# Epoch 82/200
# 11/11 [==============================] - 5s 447ms/step - loss: 0.0260 - val_loss: 0.0307
# Epoch 83/200
# 11/11 [==============================] - 5s 409ms/step - loss: 0.0263 - val_loss: 0.0300
# Epoch 84/200
# 11/11 [==============================] - 4s 402ms/step - loss: 0.0262 - val_loss: 0.0308
# Epoch 85/200
# 11/11 [==============================] - 4s 364ms/step - loss: 0.0261 - val_loss: 0.0301
# Epoch 86/200
# 11/11 [==============================] - 4s 388ms/step - loss: 0.0261 - val_loss: 0.0303
# Epoch 87/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.0258 - val_loss: 0.0300
# Epoch 88/200
# 11/11 [==============================] - 5s 451ms/step - loss: 0.0261 - val_loss: 0.0308
# Epoch 89/200
# 11/11 [==============================] - 5s 423ms/step - loss: 0.0260 - val_loss: 0.0299
# Epoch 90/200
# 11/11 [==============================] - 7s 618ms/step - loss: 0.0258 - val_loss: 0.0303
# Epoch 91/200
# 11/11 [==============================] - 4s 358ms/step - loss: 0.0261 - val_loss: 0.0299
# Epoch 92/200
# 11/11 [==============================] - 4s 374ms/step - loss: 0.0263 - val_loss: 0.0306
# Epoch 93/200
# 11/11 [==============================] - 5s 410ms/step - loss: 0.0258 - val_loss: 0.0297
# Epoch 94/200
# 11/11 [==============================] - 5s 411ms/step - loss: 0.0256 - val_loss: 0.0300
# Epoch 95/200
# 11/11 [==============================] - 4s 401ms/step - loss: 0.0256 - val_loss: 0.0299
# Epoch 96/200
# 11/11 [==============================] - 5s 472ms/step - loss: 0.0262 - val_loss: 0.0305
# Epoch 97/200
# 11/11 [==============================] - 5s 450ms/step - loss: 0.0257 - val_loss: 0.0296
# Epoch 98/200
# 11/11 [==============================] - 5s 436ms/step - loss: 0.0254 - val_loss: 0.0296
# Epoch 99/200
# 11/11 [==============================] - 4s 360ms/step - loss: 0.0258 - val_loss: 0.0304
# Epoch 100/200
# 11/11 [==============================] - 4s 388ms/step - loss: 0.0259 - val_loss: 0.0296
# Epoch 101/200
# 11/11 [==============================] - 5s 437ms/step - loss: 0.0258 - val_loss: 0.0299
# Epoch 102/200
# 11/11 [==============================] - 5s 471ms/step - loss: 0.0254 - val_loss: 0.0297
# Epoch 103/200
# 11/11 [==============================] - 4s 366ms/step - loss: 0.0255 - val_loss: 0.0302
# Epoch 104/200
# 11/11 [==============================] - 5s 412ms/step - loss: 0.0258 - val_loss: 0.0298
# Epoch 105/200
# 11/11 [==============================] - 4s 375ms/step - loss: 0.0260 - val_loss: 0.0300
# Epoch 106/200
# 11/11 [==============================] - 6s 586ms/step - loss: 0.0254 - val_loss: 0.0295
# Epoch 107/200
# 11/11 [==============================] - 5s 420ms/step - loss: 0.0255 - val_loss: 0.0299
# Epoch 108/200
# 11/11 [==============================] - 4s 372ms/step - loss: 0.0259 - val_loss: 0.0295
# Epoch 109/200
# 11/11 [==============================] - 4s 388ms/step - loss: 0.0252 - val_loss: 0.0296
# Epoch 110/200
# 11/11 [==============================] - 4s 391ms/step - loss: 0.0254 - val_loss: 0.0293
# Epoch 111/200
# 11/11 [==============================] - 4s 403ms/step - loss: 0.0252 - val_loss: 0.0296
# Epoch 112/200
# 11/11 [==============================] - 5s 435ms/step - loss: 0.0258 - val_loss: 0.0294
# Epoch 113/200
# 11/11 [==============================] - 4s 388ms/step - loss: 0.0257 - val_loss: 0.0299
# Epoch 114/200
# 11/11 [==============================] - 4s 394ms/step - loss: 0.0252 - val_loss: 0.0293
# Epoch 115/200
# 11/11 [==============================] - 4s 392ms/step - loss: 0.0251 - val_loss: 0.0297
# Epoch 116/200
# 11/11 [==============================] - 5s 444ms/step - loss: 0.0250 - val_loss: 0.0293
# Epoch 117/200
# 11/11 [==============================] - 4s 369ms/step - loss: 0.0251 - val_loss: 0.0295
# Epoch 118/200
# 11/11 [==============================] - 4s 382ms/step - loss: 0.0256 - val_loss: 0.0297
# Epoch 119/200
# 11/11 [==============================] - 4s 405ms/step - loss: 0.0253 - val_loss: 0.0294
# Epoch 120/200
# 11/11 [==============================] - 4s 383ms/step - loss: 0.0254 - val_loss: 0.0296
# Epoch 121/200
# 11/11 [==============================] - 4s 351ms/step - loss: 0.0250 - val_loss: 0.0291
# Epoch 122/200
# 11/11 [==============================] - 4s 378ms/step - loss: 0.0250 - val_loss: 0.0294
# Epoch 123/200
# 11/11 [==============================] - 4s 386ms/step - loss: 0.0253 - val_loss: 0.0293
# Epoch 124/200
# 11/11 [==============================] - 4s 383ms/step - loss: 0.0252 - val_loss: 0.0295
# Epoch 125/200
# 11/11 [==============================] - 4s 350ms/step - loss: 0.0251 - val_loss: 0.0291
# Epoch 126/200
# 11/11 [==============================] - 4s 364ms/step - loss: 0.0253 - val_loss: 0.0300
# Epoch 127/200
# 11/11 [==============================] - 5s 415ms/step - loss: 0.0254 - val_loss: 0.0293
# Epoch 128/200
# 11/11 [==============================] - 4s 382ms/step - loss: 0.0251 - val_loss: 0.0292
# Epoch 129/200
# 11/11 [==============================] - 4s 349ms/step - loss: 0.0248 - val_loss: 0.0292
# Epoch 130/200
# 11/11 [==============================] - 4s 374ms/step - loss: 0.0254 - val_loss: 0.0299
# Epoch 131/200
# 11/11 [==============================] - 4s 369ms/step - loss: 0.0250 - val_loss: 0.0289
# Epoch 132/200
# 11/11 [==============================] - 4s 389ms/step - loss: 0.0248 - val_loss: 0.0298
# Epoch 133/200
# 11/11 [==============================] - 4s 386ms/step - loss: 0.0251 - val_loss: 0.0292
# Epoch 134/200
# 11/11 [==============================] - 4s 382ms/step - loss: 0.0252 - val_loss: 0.0294
# Epoch 135/200
# 11/11 [==============================] - 5s 466ms/step - loss: 0.0248 - val_loss: 0.0288
# Epoch 136/200
# 11/11 [==============================] - 5s 498ms/step - loss: 0.0246 - val_loss: 0.0290
# Epoch 137/200
# 11/11 [==============================] - 5s 470ms/step - loss: 0.0246 - val_loss: 0.0288
# Epoch 138/200
# 11/11 [==============================] - 4s 402ms/step - loss: 0.0247 - val_loss: 0.0292
# Epoch 139/200
# 11/11 [==============================] - 5s 416ms/step - loss: 0.0250 - val_loss: 0.0289
# Epoch 140/200
# 11/11 [==============================] - 4s 370ms/step - loss: 0.0251 - val_loss: 0.0298
# Epoch 141/200
# 11/11 [==============================] - 5s 417ms/step - loss: 0.0248 - val_loss: 0.0288
# Epoch 142/200
# 11/11 [==============================] - 4s 386ms/step - loss: 0.0244 - val_loss: 0.0287
# Epoch 143/200
# 11/11 [==============================] - 5s 474ms/step - loss: 0.0250 - val_loss: 0.0293
# Epoch 144/200
# 11/11 [==============================] - 5s 496ms/step - loss: 0.0247 - val_loss: 0.0288
# Epoch 145/200
# 11/11 [==============================] - 5s 445ms/step - loss: 0.0247 - val_loss: 0.0294
# Epoch 146/200
# 11/11 [==============================] - 5s 462ms/step - loss: 0.0250 - val_loss: 0.0289
# Epoch 147/200
# 11/11 [==============================] - 5s 471ms/step - loss: 0.0246 - val_loss: 0.0289
# Epoch 148/200
# 11/11 [==============================] - 5s 452ms/step - loss: 0.0247 - val_loss: 0.0293
# Epoch 149/200
# 11/11 [==============================] - 5s 446ms/step - loss: 0.0247 - val_loss: 0.0290
# Epoch 150/200
# 11/11 [==============================] - 5s 410ms/step - loss: 0.0246 - val_loss: 0.0289
# Epoch 151/200
# 11/11 [==============================] - 4s 394ms/step - loss: 0.0247 - val_loss: 0.0289
# Epoch 152/200
# 11/11 [==============================] - 4s 392ms/step - loss: 0.0245 - val_loss: 0.0289
# Epoch 153/200
# 11/11 [==============================] - 5s 444ms/step - loss: 0.0247 - val_loss: 0.0290
# Epoch 154/200
# 11/11 [==============================] - 5s 447ms/step - loss: 0.0244 - val_loss: 0.0287
# Epoch 155/200
# 11/11 [==============================] - 5s 437ms/step - loss: 0.0247 - val_loss: 0.0294
# Epoch 156/200
# 11/11 [==============================] - 5s 426ms/step - loss: 0.0249 - val_loss: 0.0286
# Epoch 157/200
# 11/11 [==============================] - 5s 455ms/step - loss: 0.0247 - val_loss: 0.0290
# Epoch 158/200
# 11/11 [==============================] - 5s 432ms/step - loss: 0.0244 - val_loss: 0.0287
# Epoch 159/200
# 11/11 [==============================] - 5s 458ms/step - loss: 0.0247 - val_loss: 0.0291
# Epoch 160/200
# 11/11 [==============================] - 5s 486ms/step - loss: 0.0245 - val_loss: 0.0284
# Epoch 161/200
# 11/11 [==============================] - 5s 418ms/step - loss: 0.0245 - val_loss: 0.0292
# Epoch 162/200
# 11/11 [==============================] - 5s 430ms/step - loss: 0.0246 - val_loss: 0.0284
# Epoch 163/200
# 11/11 [==============================] - 4s 404ms/step - loss: 0.0240 - val_loss: 0.0283
# Epoch 164/200
# 11/11 [==============================] - 4s 397ms/step - loss: 0.0241 - val_loss: 0.0288
# Epoch 165/200
# 11/11 [==============================] - 4s 405ms/step - loss: 0.0243 - val_loss: 0.0285
# Epoch 166/200
# 11/11 [==============================] - 5s 411ms/step - loss: 0.0245 - val_loss: 0.0291
# Epoch 167/200
# 11/11 [==============================] - 4s 368ms/step - loss: 0.0244 - val_loss: 0.0286
# Epoch 168/200
# 11/11 [==============================] - 4s 375ms/step - loss: 0.0246 - val_loss: 0.0293
# Epoch 169/200
# 11/11 [==============================] - 4s 376ms/step - loss: 0.0244 - val_loss: 0.0286
# Epoch 170/200
# 11/11 [==============================] - 4s 375ms/step - loss: 0.0242 - val_loss: 0.0286
# Epoch 171/200
# 11/11 [==============================] - 4s 369ms/step - loss: 0.0241 - val_loss: 0.0286
# Epoch 172/200
# 11/11 [==============================] - 5s 411ms/step - loss: 0.0244 - val_loss: 0.0291
# Epoch 173/200
# 11/11 [==============================] - 4s 383ms/step - loss: 0.0243 - val_loss: 0.0283
# Epoch 174/200
# 11/11 [==============================] - 5s 412ms/step - loss: 0.0243 - val_loss: 0.0294
# Epoch 175/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.0244 - val_loss: 0.0286
# Epoch 176/200
# 11/11 [==============================] - 5s 414ms/step - loss: 0.0243 - val_loss: 0.0287
# Epoch 177/200
# 11/11 [==============================] - 4s 392ms/step - loss: 0.0244 - val_loss: 0.0285
# Epoch 178/200
# 11/11 [==============================] - 5s 423ms/step - loss: 0.0245 - val_loss: 0.0288
# Epoch 179/200
# 11/11 [==============================] - 4s 386ms/step - loss: 0.0243 - val_loss: 0.0285
# Epoch 180/200
# 11/11 [==============================] - 5s 440ms/step - loss: 0.0244 - val_loss: 0.0284
# Epoch 181/200
# 11/11 [==============================] - 5s 445ms/step - loss: 0.0238 - val_loss: 0.0281
# Epoch 182/200
# 11/11 [==============================] - 5s 441ms/step - loss: 0.0238 - val_loss: 0.0281
# Epoch 183/200
# 11/11 [==============================] - 5s 435ms/step - loss: 0.0238 - val_loss: 0.0281
# Epoch 184/200
# 11/11 [==============================] - 4s 377ms/step - loss: 0.0243 - val_loss: 0.0295
# Epoch 185/200
# 11/11 [==============================] - 5s 428ms/step - loss: 0.0245 - val_loss: 0.0282
# Epoch 186/200
# 11/11 [==============================] - 4s 386ms/step - loss: 0.0241 - val_loss: 0.0285
# Epoch 187/200
# 11/11 [==============================] - 5s 431ms/step - loss: 0.0238 - val_loss: 0.0281
# Epoch 188/200
# 11/11 [==============================] - 4s 408ms/step - loss: 0.0239 - val_loss: 0.0282
# Epoch 189/200
# 11/11 [==============================] - 5s 418ms/step - loss: 0.0237 - val_loss: 0.0281
# Epoch 190/200
# 11/11 [==============================] - 4s 393ms/step - loss: 0.0241 - val_loss: 0.0288
# Epoch 191/200
# 11/11 [==============================] - 5s 437ms/step - loss: 0.0241 - val_loss: 0.0282
# Epoch 192/200
# 11/11 [==============================] - 4s 379ms/step - loss: 0.0243 - val_loss: 0.0288
# Epoch 193/200
# 11/11 [==============================] - 5s 429ms/step - loss: 0.0240 - val_loss: 0.0281
# Epoch 194/200
# 11/11 [==============================] - 5s 440ms/step - loss: 0.0241 - val_loss: 0.0287
# Epoch 195/200
# 11/11 [==============================] - 5s 418ms/step - loss: 0.0244 - val_loss: 0.0282
# Epoch 196/200
# 11/11 [==============================] - 4s 405ms/step - loss: 0.0238 - val_loss: 0.0282
# Epoch 197/200
# 11/11 [==============================] - 5s 414ms/step - loss: 0.0239 - val_loss: 0.0284
# Epoch 198/200
# 11/11 [==============================] - 5s 448ms/step - loss: 0.0239 - val_loss: 0.0281
# Epoch 199/200
# 11/11 [==============================] - 5s 437ms/step - loss: 0.0236 - val_loss: 0.0278
# Epoch 200/200
# 11/11 [==============================] - 5s 447ms/step - loss: 0.0236 - val_loss: 0.0284

# %%
model_filepath = 'models/model1.keras'   #Bruno pour ne pas faire l'entrainement

# %%
# Training continues after improvement stops for the number of epochs equivalent to the 'patience' hyper-parameter
# To get back the model that performed best on the validation set we load the checkpointed model from disk:
model = keras.models.load_model(model_filepath)

# %%
model_filepath
# Out:
# 'models/model1.keras'

# %%
# Test the model by viewing a sample of original and reconstructed images
data_list = []
batch_index = 0
while batch_index <= train_generator.batch_index:
    data = train_generator.next()
    data_list.append(data[0])
    batch_index = batch_index + 1

predicted = model.predict(data_list[0])
no_of_samples = 2
_, axs = plt.subplots(no_of_samples, 2, figsize=(15, 10))
axs = axs.flatten()
imgs = []

for i in range(no_of_samples):
    imgs.append(data_list[i][i])
    imgs.append(predicted[i])
for img, ax in zip(imgs, axs):
    ax.imshow(img)
plt.show()

# %%
# We want the difference the difference in error between the validation (normal) images and anomalous images to be as high as possible
print(f"Error on validation set:{model.evaluate_generator(validation_generator)}, error on anomaly set:{model.evaluate_generator(anomaly_generator)}")

# %% [markdown]
# # Extracting the encoded image

# %%
# We build a replica of the first half of the auto-encoder (the encoder only)
# This network takes a an image which is 96x96x3 and compresses it down to a 3x3x3 tensor
encoder_replica = Sequential()
encoder_replica.add(Conv2D(16, (3, 3), padding='same',activation='relu', input_shape=(96, 96, 3), weights=model.layers[0].get_weights()) )
encoder_replica.add(MaxPooling2D(pool_size=(4,4), padding='same'))
encoder_replica.add(Conv2D(8,(3, 3),activation='relu',  padding='same', weights=model.layers[2].get_weights()))
encoder_replica.add(MaxPooling2D(pool_size=(4,4), padding='same'))
encoder_replica.add(Conv2D(3,(3, 3),activation='relu',  padding='same', weights=model.layers[4].get_weights()))
encoder_replica.add(MaxPooling2D(pool_size=(2,2), padding='same'))
encoder_replica.summary()

# %%
# Creating encoded (compressed versions of the training, validation and anomalous images) and getting their density
# The SKLearn kernel density function only works with 1D arrays so we need to flatten the tensors created by the encoder
encoded_images = encoder_replica.predict_generator(train_generator)
encoded_images_flat = [np.reshape(img, (27)) for img in encoded_images]

validation_encoded = encoder_replica.predict_generator(validation_generator)
val_enc_flat = [np.reshape(img, (27)) for img in validation_encoded]

anom_encoded = encoder_replica.predict_generator(anomaly_generator)
anom_enc_flat = [np.reshape(img, (27)) for img in anom_encoded]

# %%
# Kernel Density Estimation of the encoded vectors
kde = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(encoded_images_flat)
training_density_scores = kde.score_samples(encoded_images_flat) 
validation_density_scores = kde.score_samples(val_enc_flat)
anomaly_density_scores = kde.score_samples(anom_enc_flat)

# Plotting the density distributions of the training (normal), validation (normal) and anomalous images
# Ideally we want to see high separation between the normal and anomalous classes
plt.figure(figsize = (10,7))
plt.title('Distribution of Density Scores')
plt.hist(training_density_scores, 12, alpha=0.5, label='Training Normal')
plt.hist(validation_density_scores, 12, alpha=0.5, label='Validation Normal')
plt.hist(anomaly_density_scores, 12, alpha=0.5, label='Anomalies')
plt.legend(loc='upper right')
plt.xlabel('Density Score')

plt.show()

# %%
# Creat a function that will classify whether an unseen image is normal or an anomaly
# Low density and high reconstruction error mean that the image is likely to be anomalous
def check_anomaly(img_path):
    density_threshold = 0 # This threshold was chosen based on looking at the distribution of the density scores of the normal class (validation set)
    reconstruction_error_threshold = 0.04 # This threshold was chosen based on looking at the distribution of reconstruction errors of the normal class
    img  = Image.open(img_path)
    img = np.array(img.resize((96,96), Image.ANTIALIAS))
    img = img / 255
    encoded_img = encoder_replica.predict([[img]]) # Create a compressed version of the image using the encoder
    encoded_img = [np.reshape(img, (27)) for img in encoded_img] # Flatten the compressed image
    density = kde.score_samples(encoded_img)[0] # get a density score for the new image
#     print(f'density: {density}')
    reconstruction = model.predict([[img]])
    reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)
#     print(f'reconstruction_error: {reconstruction_error}')
    if density < density_threshold or reconstruction_error > reconstruction_error_threshold:
        return True
    else:
        return False

# %%
# Check what proportion of onion images are classified as anomalous
onion_files = []
for (dirpath, dirnames, filenames) in os.walk('onions'):
    for x in filenames:
        if x.endswith(".jpg"):
            onion_files.append(os.path.join(dirpath, x))

onion_predictions = []
for file in onion_files:
    onion_predictions.append(check_anomaly(file))
print(sum(onion_predictions)/len(onion_predictions))

# %%
# Check what proportion of apples are classified as anomalous (we hope that this will be close to zero)
apples_test = []
for (dirpath, dirnames, filenames) in os.walk('robusto_test'):
    for x in filenames:
        if x.endswith(".jpg"):
            apples_test.append(os.path.join(dirpath, x))

apples_predictions = []
for file in apples_test:
    apples_predictions.append(check_anomaly(file))
print(sum(apples_predictions)/len(apples_predictions))

# %%
# Check what proportion of aubergines/eggplants get classed as anomalous.
eggplant_test = []
for (dirpath, dirnames, filenames) in os.walk('eggplant'):
    for x in filenames:
        if x.endswith(".jpg"):
            eggplant_test.append(os.path.join(dirpath, x))

eggplant_predictions = []
for file in eggplant_test:
    eggplant_predictions.append(check_anomaly(file))
print(sum(eggplant_predictions)/len(eggplant_predictions))

# %%
peppers_test = []
for (dirpath, dirnames, filenames) in os.walk('peppers'):
    for x in filenames:
        if x.endswith(".jpg"):
            peppers_test.append(os.path.join(dirpath, x))

peppers_predictions = []
for file in peppers_test:
    peppers_predictions.append(check_anomaly(file))
print(sum(peppers_predictions)/len(peppers_predictions))

# %%
len(peppers_predictions)
